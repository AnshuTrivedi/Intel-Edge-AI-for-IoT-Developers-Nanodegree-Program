# %% [markdown]
# ## Introduction to Intel VTune

# %% [markdown]
# * [VTune Amplifier]((https://software.intel.com/content/www/us/en/develop/tools/vtune-profiler.html)) is an advanced profiler that can be used to find hotspots in our application code.
#
# In this section, we will get an introduction to how VTune Amplifier works.
# * `We will learn how to load and run our application on to the Intel VTune and then see how much time it takes to run and the distribution of the CPU resources that were allocated to running the application.`
#
# To be able to follow along with this video, you will need to download and install VTune Amplifier.
# * You can download VTune Amplifier from [here](https://software.intel.com/en-us/vtune/choose-download#standalone) and you can get detailed instructions about how to install and run it from [here](https://software.intel.com/en-us/get-started-with-vtune) (on the left-hand side of the page, you can select instructions for Windows, Mac, or Linux).
#
# You will also need an application that you can test. I will be working on a simple application that I wrote. You can either download my code [here](https://video.udacity-data.com/topher/2020/March/5e74dc91_vtune-project/vtune-project.zip), or use the application that you wrote for the exercises in the previous lesson.

# %% [markdown]
# * The `effective time` is the total time that the CPU or hardware device was busy in our application.
# * `Effective Time + Spin Time + Overhead Time is the total time that your application ran for. It is also known as elapsed time.`
# * `Spin time`: it is the time when CPU or hardware devices were not being utilized or waiting

# %% [markdown]
# `Our application should try to use as many of CPU cores/threads as possible`

# %% [markdown]
# ## Exercise: Profiling using Intel VTune

# %% [markdown]
# Now that you have seen how to run a simple profile of your application code, it is time to test your understanding. Here are your tasks for this exercise:

# %%
from IPython.display import Image
Image(filename='tasks.png')
